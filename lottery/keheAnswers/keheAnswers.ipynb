# %%
import urllib2
from bs4 import BeautifulSoup

newLinkPool = []

url = 'https://discuss.leetcode.com/user/caikehe?page='
urls = [url + str(i) for i in xrange(76, 0, -1)] # till 77
with open('keheAnswers.html', 'w') as f:
    for url in urls:
        req = urllib2.Request(url, headers={'User-Agent' : "Magic Browser"})
        webpage = urllib2.urlopen(req)
        pageContent = webpage.read()
         
        soup = BeautifulSoup(pageContent)
         
        links = soup.findAll('a', {'class':'topic-title'})
        sublinks = [link['href'] for link in links] 
        # print stuff
        
        # [u'/post/167259', u'/post/51280', u'/post/51273', u'/post/51268', u'/post/49753', u'/post/49749', u'/post/47067', u'/post/47066', u'/post/46998', u'/post/46861']
        
        # one link to one topic
        postBase = 'https://discuss.leetcode.com'
        newLinks = [postBase + subLink for subLink in sublinks]
        
        for newLink in newLinks:
    #         newLink = 'https://discuss.leetcode.com/post/167259'
            req = urllib2.Request(newLink, headers={'User-Agent' : "Magic Browser"})
            webpage = urllib2.urlopen(req)
            pageContent = webpage.read()
            
            soup = BeautifulSoup(pageContent)
            
            links = soup.findAll('span', {'itemprop':'title'})
            # get text from span section
            title = links[-2].text
            topic = links[-1].text
            # stuff = [link['href'] for link in links] 
            print title, topic, newLink
            newLine = '<br/><strong>' + title + '</strong>, <span>' + topic + '</span>, <a href="' + newLink + '">' + str(newLink) + '</a> <br />'
            f.write('\n' + newLine)
# Out:
# 				Rectangle Area
#
#
# 				Easy python code
#
# https://discuss.leetcode.com//post/76079
#
# 				Invert Binary Tree
#
#
# 				Python DFS / BFS solution
#
# https://discuss.leetcode.com//post/76075
#
# 				Invert Binary Tree
#
#
# 				4 Line Python Solution (52 ms)
#
# https://discuss.leetcode.com//post/76074
#
# 				Summary Ranges
#
#
# 				My easy to understand Python solution
#
# https://discuss.leetcode.com//post/19619
#
# 				Invert Binary Tree
#
#
# 				4 Line Python Solution (52 ms)
#
# https://discuss.leetcode.com//post/76397
#
# 				Symmetric Tree
#
#
# 				Python iterative way using a queue
#
# https://discuss.leetcode.com//post/76395
#
# 				Unique Binary Search Trees
#
#
# 				Why res = res*2*(2*i-1)/(i+1) works, res *= 2*(2*i-1)/(i+1) does not work?
#
# https://discuss.leetcode.com//post/19934
#
# 				Balanced Binary Tree
#
#
# 				Where wrong with my python code?
#
# https://discuss.leetcode.com//post/76307
#
# 				Balanced Binary Tree
#
#
# 				Where wrong with my python code?
#
# https://discuss.leetcode.com//post/76305
#
# 				Balanced Binary Tree
#
#
# 				My python solution with horrible run time
#
# https://discuss.leetcode.com//post/76304
#
# 				Contains Duplicate II
#
#
# 				My simple python code, linear time, 48ms accepted
#
# https://discuss.leetcode.com//post/76099
#
# 				Valid Sudoku
#
#
# 				An easy to understand Python solution
#
# https://discuss.leetcode.com//post/76095
#
# 				Valid Sudoku
#
#
# 				An easy to understand Python solution
#
# https://discuss.leetcode.com//post/19634
#
# 				Add Binary
#
#
# 				Python iterative solution - O(n) 66ms
#
# https://discuss.leetcode.com//post/76083
#
# 				Path Sum II
#
#
# 				Short python solution
#
# https://discuss.leetcode.com//post/76608
#
# 				Path Sum II
#
#
# 				Python recursive solution - O(n) 116ms
#
# https://discuss.leetcode.com//post/76605
#
# 				Path Sum
#
#
# 				Python - 80ms - Recursive DFS Pre-Order solution - O(n)
#
# https://discuss.leetcode.com//post/76593
#
# 				Path Sum
#
#
# 				Python solutions (DFS recursively, DFS+stack, BFS+queue)
#
# https://discuss.leetcode.com//post/20118
#
# 				Populating Next Right Pointers in Each Node II
#
#
# 				Just convert common BFS solution to O(1)  space, a simple python code
#
# https://discuss.leetcode.com//post/76591
#
# 				Populating Next Right Pointers in Each Node
#
#
# 				Python solutions (Recursively, BFS+queue, DFS+stack)
#
# https://discuss.leetcode.com//post/20078
#
# 				Populating Next Right Pointers in Each Node
#
#
# 				Simple Python recursive solution
#
# https://discuss.leetcode.com//post/76539
#
# 				Same Tree
#
#
# 				Python Recursive solution and DFS Iterative solution with stack and BFS Iterative solution with queue
#
# https://discuss.leetcode.com//post/20038
#
# 				Same Tree
#
#
# 				My 44ms python solution
#
# https://discuss.leetcode.com//post/76492
#
# 				Sum Root to Leaf Numbers
#
#
# 				Two solutions in Python recursive and dfs
#
# https://discuss.leetcode.com//post/76490
#
# 				Binary Tree Level Order Traversal
#
#
# 				Python short dfs solution
#
# https://discuss.leetcode.com//post/20257
#
# 				Unique Binary Search Trees
#
#
# 				Why res = res*2*(2*i-1)/(i+1) works, res *= 2*(2*i-1)/(i+1) does not work?
#
# https://discuss.leetcode.com//post/76688
#
# 				Binary Tree Preorder Traversal
#
#
# 				Python iterative solution
#
# https://discuss.leetcode.com//post/76673
#
# 				Binary Tree Preorder Traversal
#
#
# 				My python solution
#
# https://discuss.leetcode.com//post/76671
#
# 				Kth Smallest Element in a BST
#
#
# 				Python iterative solution based on in order traversal by using stack
#
# https://discuss.leetcode.com//post/20152
#
# 				Binary Tree Inorder Traversal
#
#
# 				Simple iterative python solution with explanations - 56ms
#
# https://discuss.leetcode.com//post/76651
#
# 				Maximum Depth of Binary Tree
#
#
# 				Python solution (BFS + deque/queue)
#
# https://discuss.leetcode.com//post/20143
#
# 				Minimum Depth of Binary Tree
#
#
# 				Share my python answer
#
# https://discuss.leetcode.com//post/76640
#
# 				Minimum Depth of Binary Tree
#
#
# 				My solution in python
#
# https://discuss.leetcode.com//post/76637
#
# 				Path Sum II
#
#
# 				Python solutions (Recursively, BFS+queue, DFS+stack)
#
# https://discuss.leetcode.com//post/20129
#
# 				Construct Binary Tree from Preorder and Inorder Traversal
#
#
# 				O(n) simple python solution
#
# https://discuss.leetcode.com//post/77017
#
# 				Construct Binary Tree from Preorder and Inorder Traversal
#
#
# 				Why my recursive python solution is MLE?
#
# https://discuss.leetcode.com//post/77006
#
# 				Convert Sorted Array to Binary Search Tree
#
#
# 				Simple python recursive solution , 10 line
#
# https://discuss.leetcode.com//post/76974
#
# 				Count Complete Tree Nodes
#
#
# 				My python solution in O(lgn * lgn) time
#
# https://discuss.leetcode.com//post/76892
#
# 				Binary Search Tree Iterator
#
#
# 				My solutions in 3 languages with Stack
#
# https://discuss.leetcode.com//post/76814
#
# 				Binary Search Tree Iterator
#
#
# 				My python solution
#
# https://discuss.leetcode.com//post/76813
#
# 				Binary Search Tree Iterator
#
#
# 				Simple Python solution
#
# https://discuss.leetcode.com//post/76811
#
# 				Flatten Binary Tree to Linked List
#
#
# 				Python easy to understand recursive solution with explaination.
#
# https://discuss.leetcode.com//post/76809
#
# 				Flatten Binary Tree to Linked List
#
#
# 				Python easy to understand recursive solution with explaination.
#
# https://discuss.leetcode.com//post/20260
#
# 				Binary Tree Level Order Traversal
#
#
# 				Python short dfs solution
#
# https://discuss.leetcode.com//post/76803
#
# 				Merge k Sorted Lists
#
#
# 				Python Recursive Solution. How to compute the Complexity in recursive Algorithm?s]
#
# https://discuss.leetcode.com//post/77094
#
# 				Merge k Sorted Lists
#
#
# 				Python Recursive Solution. How to compute the Complexity in recursive Algorithm?s]
#
# https://discuss.leetcode.com//post/77093
#
# 				Swap Nodes in Pairs
#
#
# 				Python recursive solution - O(n)
#
# https://discuss.leetcode.com//post/77041
#
# 				Merge Two Sorted Lists
#
#
# 				Python recursive solution with only 11 lines, easy to understand
#
# https://discuss.leetcode.com//post/77037
#
# 				Merge Two Sorted Lists
#
#
# 				Any good python solution?
#
# https://discuss.leetcode.com//post/77035
#
# 				Merge Two Sorted Lists
#
#
# 				My Python solution using a guard node
#
# https://discuss.leetcode.com//post/77034
#
# 				Remove Nth Node From End of List
#
#
# 				My easy understanding 48ms python solution
#
# https://discuss.leetcode.com//post/77029
#
# 				Binary Tree Zigzag Level Order Traversal
#
#
# 				Python short iterative solution with explanation.
#
# https://discuss.leetcode.com//post/20417
#
# 				Binary Tree Right Side View
#
#
# 				Python solutions (DFS recursively, DFS+stack, BFS+queue)
#
# https://discuss.leetcode.com//post/77024
#
# 				Binary Tree Right Side View
#
#
# 				Python solutions (DFS recursively, DFS+stack, BFS+queue)
#
# https://discuss.leetcode.com//post/20412
#
# 				Convert Sorted List to Binary Search Tree
#
#
# 				Runtime Error? [Python]
#
# https://discuss.leetcode.com//post/77260
#
# 				Reverse Linked List II
#
#
# 				Question on details of Python
#
# https://discuss.leetcode.com//post/77249
#
# 				Swap Nodes in Pairs
#
#
# 				Python concise iterative and recursive solutions.
#
# https://discuss.leetcode.com//post/20526
#
# 				Remove Duplicates from Sorted List II
#
#
# 				Python solution with dictionary, easy to understand.
#
# https://discuss.leetcode.com//post/20522
#
# 				Remove Duplicates from Sorted List
#
#
# 				Python one pass solution and Python solution with dictionary.
#
# https://discuss.leetcode.com//post/20516
#
# 				Remove Duplicates from Sorted List
#
#
# 				Simple 7 line python solution - 84ms
#
# https://discuss.leetcode.com//post/77129
#
# 				Rotate List
#
#
# 				An iterative Python solution - O(2n) 89ms
#
# https://discuss.leetcode.com//post/77123
#
# 				Reverse Linked List
#
#
# 				Python iterative and recursive solution, both O(n) time complexity.
#
# https://discuss.leetcode.com//post/20501
#
# 				Merge k Sorted Lists
#
#
# 				A Fast Java solution using PriorityQueue.  TimeComplexity o(n*k*lg(k))
#
# https://discuss.leetcode.com//post/77096
#
# 				Merge k Sorted Lists
#
#
# 				Python solution using Merge Sort-O(n*log(k))
#
# https://discuss.leetcode.com//post/77095
#
# 				Reorder List
#
#
# 				Python in place solution with comments (two pointers).
#
# https://discuss.leetcode.com//post/20648
#
# 				Linked List Cycle II
#
#
# 				Sharing my Python solution
#
# https://discuss.leetcode.com//post/77295
#
# 				Linked List Cycle II
#
#
# 				Python solution with comments.
#
# https://discuss.leetcode.com//post/20643
#
# 				Linked List Cycle
#
#
# 				Python solutions (dictionary and two pointers).
#
# https://discuss.leetcode.com//post/20642
#
# 				Palindrome Linked List
#
#
# 				Reversing a list is not considered "O(1) space"
#
# https://discuss.leetcode.com//post/77287
#
# 				Palindrome Linked List
#
#
# 				Short and Simple Python Palindrome Linked List
#
# https://discuss.leetcode.com//post/77285
#
# 				Palindrome Linked List
#
#
# 				Python easy to understand solution with comments (operate nodes directly).
#
# https://discuss.leetcode.com//post/20637
#
# 				Linked List Cycle
#
#
# 				Classical Python solution
#
# https://discuss.leetcode.com//post/77277
#
# 				Copy List with Random Pointer
#
#
# 				Python solution without using dictionary.
#
# https://discuss.leetcode.com//post/20627
#
# 				Convert Sorted List to Binary Search Tree
#
#
# 				Python solutions (convert to array first, top-down approach, bottom-up approach)
#
# https://discuss.leetcode.com//post/20620
#
# 				Insertion Sort List
#
#
# 				Accepted python solution
#
# https://discuss.leetcode.com//post/77324
#
# 				Insertion Sort List
#
#
# 				Thoughts from a Google interviewer
#
# https://discuss.leetcode.com//post/77323
#
# 				Sort List
#
#
# 				Costed 2536ms using python, how to optimize?
#
# https://discuss.leetcode.com//post/77319
#
# 				Remove Linked List Elements
#
#
# 				Could anyone find the bug on my code? I'm trying to change the value of nodes.
#
# https://discuss.leetcode.com//post/20654
#
# 				Remove Linked List Elements
#
#
# 				Share my simple python solution 152ms
#
# https://discuss.leetcode.com//post/77318
#
# 				Delete Node in a Linked List
#
#
# 				Python two lines solution, copy value and then delete the next node.
#
# https://discuss.leetcode.com//post/20651
#
# 				Delete Node in a Linked List
#
#
# 				Simple Python Solution
#
# https://discuss.leetcode.com//post/77309
#
# 				Delete Node in a Linked List
#
#
# 				Why LeetCode accepted such stupid question?
#
# https://discuss.leetcode.com//post/77308
#
# 				Palindrome Linked List
#
#
# 				Python easy to understand solution with comments (operate nodes directly).
#
# https://discuss.leetcode.com//post/77306
#
# 				Reorder List
#
#
# 				Python Iterative AC Code, reverse the second half first
#
# https://discuss.leetcode.com//post/77304
#
# 				Combinations
#
#
# 				Easy to understand  Python solution with comments.
#
# https://discuss.leetcode.com//post/20783
#
# 				Subsets II
#
#
# 				Comparisons of Codes for Subsets and Subsets II
#
# https://discuss.leetcode.com//post/77470
#
# 				Subsets
#
#
# 				[python] Question on list.append
#
# https://discuss.leetcode.com//post/77448
#
# 				Subsets
#
#
# 				[python] Question on list.append
#
# https://discuss.leetcode.com//post/77447
#
# 				Subsets
#
#
# 				My solution using bit manipulation
#
# https://discuss.leetcode.com//post/77428
#
# 				Clone Graph
#
#
# 				[Python] I can't find anything wrong with this solution, yet it fails.
#
# https://discuss.leetcode.com//post/77415
#
# 				Clone Graph
#
#
# 				What exactly does {-1} mean!
#
# https://discuss.leetcode.com//post/77413
#
# 				Clone Graph
#
#
# 				Python solution with BFS, 120ms
#
# https://discuss.leetcode.com//post/77412
#
# 				Number of Islands
#
#
# 				4ms C DFS solution reusing grid to memoize visited squares
#
# https://discuss.leetcode.com//post/77405
#
# 				Number of Islands
#
#
# 				Python bfs solution
#
# https://discuss.leetcode.com//post/77403
#
# 				Permutations II
#
#
# 				A Python solution based on standard permutation - 130ms
#
# https://discuss.leetcode.com//post/77603
#
# 				Permutations
#
#
# 				My standard solution for Permutations using python
#
# https://discuss.leetcode.com//post/77596
#
# 				Same Tree
#
#
# 				My 44ms python solution
#
# https://discuss.leetcode.com//post/77578
#
# 				Letter Combinations of a Phone Number
#
#
# 				Python easy to understand backtracking solution.
#
# https://discuss.leetcode.com//post/20809
#
# 				Gray Code
#
#
# 				An iterative Python solution based on Gray Code definition
#
# https://discuss.leetcode.com//post/77492
#
# 				Subsets II
#
#
# 				Comparisons of Codes for Subsets and Subsets II
#
# https://discuss.leetcode.com//post/77483
#
# 				Combination Sum II
#
#
# 				Easy to understand Python solution (backtracking).
#
# https://discuss.leetcode.com//post/20790
#
# 				Combination Sum III
#
#
# 				My Python code, any improvements?
#
# https://discuss.leetcode.com//post/77479
#
# 				Combination Sum III
#
#
# 				How to analyse the time complexity of the recursive solution
#
# https://discuss.leetcode.com//post/77478
#
# 				Combination Sum III
#
#
# 				Easy to understand Python solution (backtracking).
#
# https://discuss.leetcode.com//post/20785
#
# 				Word Search
#
#
# 				Python DFS solution
#
# https://discuss.leetcode.com//post/77826
#
# 				Palindrome Partitioning
#
#
# 				Python easy to understand backtracking solution.
#
# https://discuss.leetcode.com//post/77823
#
# 				Palindrome Partitioning
#
#
# 				Python easy to understand backtracking solution.
#
# https://discuss.leetcode.com//post/21032
#
# 				Restore IP Addresses
#
#
# 				Python easy to understand solution with comments (backtracking).
#
# https://discuss.leetcode.com//post/77746
#
# 				Restore IP Addresses
#
#
# 				Python easy to understand solution with comments (backtracking).
#
# https://discuss.leetcode.com//post/20960
#
# 				Next Permutation
#
#
# 				Python solution with comments.
#
# https://discuss.leetcode.com//post/77744
#
# 				Next Permutation
#
#
# 				Python solution with comments.
#
# https://discuss.leetcode.com//post/77733
#
# 				Next Permutation
#
#
# 				Python solution with comments.
#
# https://discuss.leetcode.com//post/77725
#
# 				Next Permutation
#
#
# 				Python solution with comments.
#
# https://discuss.leetcode.com//post/20939
#
# 				Permutations II
#
#
# 				Python easy to understand backtracking solution.
#
# https://discuss.leetcode.com//post/20870
#
# 				Single Number
#
#
# 				O(n) solution, using bit operation, only 22 characters
#
# https://discuss.leetcode.com//post/78067
#
# 				Single Number
#
#
# 				One line Python solution with reduce - O(n) 48ms
#
# https://discuss.leetcode.com//post/78066
#
# 				Subsets
#
#
# 				Python easy to understand solutions (DFS recursively, Bit Manipulation, Iteratively).
#
# https://discuss.leetcode.com//post/21246
#
# 				Remove Linked List Elements
#
#
# 				Could anyone find the bug on my code? I'm trying to change the value of nodes.
#
# https://discuss.leetcode.com//post/78038
#
# 				Surrounded Regions
#
#
# 				Can anyone figure out the TLE reason on my Python BFS code?
#
# https://discuss.leetcode.com//post/21150
#
# 				Surrounded Regions
#
#
# 				Python easy to understand solution (BFS).
#
# https://discuss.leetcode.com//post/77952
#
# 				Surrounded Regions
#
#
# 				Python easy to understand solution (BFS).
#
# https://discuss.leetcode.com//post/21134
#
# 				Word Ladder
#
#
# 				My C++ bi-directional BFS solution (O(N) time, O(N) space), 64ms
#
# https://discuss.leetcode.com//post/77875
#
# 				Word Break II
#
#
# 				Python easy to understand solution (DP+DFS+Backtracking).
#
# https://discuss.leetcode.com//post/77874
#
# 				Word Break II
#
#
# 				Python easy to understand solution (DP+DFS+Backtracking).
#
# https://discuss.leetcode.com//post/21064
#
# 				Reverse Bits
#
#
# 				Different Python solutions.
#
# https://discuss.leetcode.com//post/78149
#
# 				Majority Element
#
#
# 				Python different solutions (dictionary, bit manipulation, sorting, divide and conquer, brute force, etc).
#
# https://discuss.leetcode.com//post/21280
#
# 				Number of 1 Bits
#
#
# 				Python easy to understand solution (Bit Manipulation).
#
# https://discuss.leetcode.com//post/21274
#
# 				Single Number II
#
#
# 				Python constant space solution (Bit Manipulation).
#
# https://discuss.leetcode.com//post/21271
#
# 				Repeated DNA Sequences
#
#
# 				Python one pass efficient solutions (dictionary, bit manipulation).
#
# https://discuss.leetcode.com//post/21267
#
# 				Single Number
#
#
# 				One line Python solution with reduce - O(n) 48ms
#
# https://discuss.leetcode.com//post/78087
#
# 				Reverse Integer
#
#
# 				Python two accepted solutions.
#
# https://discuss.leetcode.com//post/21260
#
# 				Reverse Integer
#
#
# 				Python Accepted Code
#
# https://discuss.leetcode.com//post/78081
#
# 				Reverse Bits
#
#
# 				Different Python solutions.
#
# https://discuss.leetcode.com//post/21254
#
# 				Single Number
#
#
# 				Python different solutions.
#
# https://discuss.leetcode.com//post/21248
#
# 				Triangle
#
#
# 				Python easy to understand solutions (top-down, bottom-up).
#
# https://discuss.leetcode.com//post/21439
#
# 				Balanced Binary Tree
#
#
# 				Where wrong with my python code?
#
# https://discuss.leetcode.com//post/78245
#
# 				Product of Array Except Self
#
#
# 				Concise Python solution, constant space (left to right then right to left).
#
# https://discuss.leetcode.com//post/21377
#
# 				Best Time to Buy and Sell Stock
#
#
# 				Python different solutions (DP).
#
# https://discuss.leetcode.com//post/21371
#
# 				Maximum Subarray
#
#
# 				Python solutions (DP O(n) space, O(1) space).
#
# https://discuss.leetcode.com//post/21368
#
# 				Maximal Square
#
#
# 				Python solutions (O(m*n), O(2*n) space).
#
# https://discuss.leetcode.com//post/21362
#
# 				Unique Binary Search Trees
#
#
# 				Python solutions (DP + Catalan number)
#
# https://discuss.leetcode.com//post/21355
#
# 				Climbing Stairs
#
#
# 				Python different solutions (bottom up, top down).
#
# https://discuss.leetcode.com//post/21347
#
# 				House Robber
#
#
# 				Easy to understand Python solutions (Dynamic Programming).
#
# https://discuss.leetcode.com//post/21339
#
# 				Bitwise AND of Numbers Range
#
#
# 				Python different solutions.
#
# https://discuss.leetcode.com//post/21336
#
# 				Interleaving String
#
#
# 				Python DP solutions (O(m*n), O(n) space), BFS, DFS.
#
# https://discuss.leetcode.com//post/21585
#
# 				Scramble String
#
#
# 				Python dp solutions (with and without memorization).
#
# https://discuss.leetcode.com//post/21575
#
# 				Edit Distance
#
#
# 				Python solutions (O(m*n), O(n) space).
#
# https://discuss.leetcode.com//post/21562
#
# 				Dungeon Game
#
#
# 				Python easy to understand solutions (O(m*n), O(n) space).
#
# https://discuss.leetcode.com//post/78454
#
# 				Dungeon Game
#
#
# 				Python easy to understand solutions (O(m*n), O(n) space).
#
# https://discuss.leetcode.com//post/21531
#
# 				Maximum Product Subarray
#
#
# 				Python solutions with different space costs (O(2*n), O(1)).
#
# https://discuss.leetcode.com//post/21492
#
# 				House Robber II
#
#
# 				Python solution (divide into two parts).
#
# https://discuss.leetcode.com//post/21483
#
# 				Unique Paths II
#
#
# 				Python different solutions (O(m*n), O(n), in place).
#
# https://discuss.leetcode.com//post/21480
#
# 				Unique Paths
#
#
# 				Python easy to understand solutions (math, dp O(m*n) and O(n) space).
#
# https://discuss.leetcode.com//post/21448
#
# 				Minimum Path Sum
#
#
# 				Python solutions (O(m*n), O(n) space).
#
# https://discuss.leetcode.com//post/21444
#
# 				Isomorphic Strings
#
#
# 				Python different solutions (dictionary, etc).
#
# https://discuss.leetcode.com//post/78589
#
# 				Isomorphic Strings
#
#
# 				Python different solutions (dictionary, etc).
#
# https://discuss.leetcode.com//post/21678
#
# 				Implement Queue using Stacks
#
#
# 				Python amortized O(1) solution (two stacks).
#
# https://discuss.leetcode.com//post/78574
#
# 				Implement Queue using Stacks
#
#
# 				Python amortized O(1) solution (two stacks).
#
# https://discuss.leetcode.com//post/78564
#
# 				Implement Queue using Stacks
#
#
# 				Python amortized O(1) solution (two stacks).
#
# https://discuss.leetcode.com//post/21668
#
# 				Implement Queue using Stacks
#
#
# 				This question could be designed better
#
# https://discuss.leetcode.com//post/78562
#
# 				Implement Stack using Queues
#
#
# 				Python easy to understand solutions (one queue, two queues).
#
# https://discuss.leetcode.com//post/21666
#
# 				Jump Game
#
#
# 				Python different solutions.
#
# https://discuss.leetcode.com//post/21603
#
# 				Jump Game
#
#
# 				Difference between DP and Greedy
#
# https://discuss.leetcode.com//post/78498
#
# 				Distinct Subsequences
#
#
# 				Python dp solutions (O(m*n), O(n) space).
#
# https://discuss.leetcode.com//post/21595
#
# 				Binary Search Tree Iterator
#
#
# 				Simple Python solution
#
# https://discuss.leetcode.com//post/78678
#
# 				Plus One
#
#
# 				Python easy to follow solutions.
#
# https://discuss.leetcode.com//post/21708
#
# 				Plus One
#
#
# 				Python solution one liner
#
# https://discuss.leetcode.com//post/78627
#
# 				Excel Sheet Column Number
#
#
# 				Maybe the fastest Python solution. 58ms.
#
# https://discuss.leetcode.com//post/78623
#
# 				Longest Common Prefix
#
#
# 				Python divide and conquer solution.
#
# https://discuss.leetcode.com//post/78620
#
# 				Longest Common Prefix
#
#
# 				A pythonic solution, 52 ms
#
# https://discuss.leetcode.com//post/78619
#
# 				Longest Common Prefix
#
#
# 				Python divide and conquer solution.
#
# https://discuss.leetcode.com//post/21703
#
# 				String to Integer (atoi)
#
#
# 				Python easy to understand solution (logic is easy to follow).
#
# https://discuss.leetcode.com//post/21697
#
# 				Subsets
#
#
# 				[python] Question on list.append
#
# https://discuss.leetcode.com//post/78610
#
# 				Rotate Array
#
#
# 				Python easy to understand solutions.
#
# https://discuss.leetcode.com//post/21690
#
# 				Valid Parentheses
#
#
# 				Python concise solution using stack.
#
# https://discuss.leetcode.com//post/21853
#
# 				Number of Digit One
#
#
# 				Python recursive solution (with comments).
#
# https://discuss.leetcode.com//post/21849
#
# 				Remove Element
#
#
# 				Python two-pointer in place solution.
#
# https://discuss.leetcode.com//post/21777
#
# 				Implement strStr()
#
#
# 				Python clear brute-force solution.
#
# https://discuss.leetcode.com//post/21775
#
# 				Count and Say
#
#
# 				Python accepted solution.
#
# https://discuss.leetcode.com//post/21774
#
# 				Length of Last Word
#
#
# 				Python different solutions.
#
# https://discuss.leetcode.com//post/21771
#
# 				Merge Sorted Array
#
#
# 				Python easy to follow solution.
#
# https://discuss.leetcode.com//post/21767
#
# 				Pascal's Triangle II
#
#
# 				Python different solutions (from left to right, from right to left and math).
#
# https://discuss.leetcode.com//post/21764
#
# 				Pascal's Triangle
#
#
# 				Python short solution.
#
# https://discuss.leetcode.com//post/21761
#
# 				Compare Version Numbers
#
#
# 				Python easy to understand solution.
#
# https://discuss.leetcode.com//post/21754
#
# 				Group Anagrams
#
#
# 				Python easy to understand solution with dictionary.
#
# https://discuss.leetcode.com//post/78973
#
# 				Group Anagrams
#
#
# 				Python easy to understand solution with dictionary.
#
# https://discuss.leetcode.com//post/22003
#
# 				Pow(x, n)
#
#
# 				Theoretically which of these two Python recursive solutions should be faster?
#
# https://discuss.leetcode.com//post/78924
#
# 				Pow(x, n)
#
#
# 				Theoretically which of these two Python recursive solutions should be faster?
#
# https://discuss.leetcode.com//post/21969
#
# 				Binary Tree Zigzag Level Order Traversal
#
#
# 				Python short iterative solution with explanation.
#
# https://discuss.leetcode.com//post/78909
#
# 				String to Integer (atoi)
#
#
# 				Python easy to understand solution (logic is easy to follow).
#
# https://discuss.leetcode.com//post/78907
#
# 				Remove Duplicates from Sorted Array
#
#
# 				The problem is that you should not use "is" here.
#
# https://discuss.leetcode.com//post/21866
#
# 				Remove Element
#
#
# 				Python two-pointer in place solution.
#
# https://discuss.leetcode.com//post/78802
#
# 				Valid Parentheses
#
#
# 				Python concise solution using stack.
#
# https://discuss.leetcode.com//post/78797
#
# 				Find Minimum in Rotated Sorted Array
#
#
# 				7-Line O(LogN) Solution
#
# https://discuss.leetcode.com//post/79110
#
# 				Find Minimum in Rotated Sorted Array
#
#
# 				Is there any rules when add '==' in the while condition checking?
#
# https://discuss.leetcode.com//post/22120
#
# 				Search in Rotated Sorted Array
#
#
# 				Python O(lgn) solution (It needs a pen and some paper to figure it out at the first time).
#
# https://discuss.leetcode.com//post/22114
#
# 				Search a 2D Matrix
#
#
# 				Python iterative and recursive solutions.
#
# https://discuss.leetcode.com//post/79104
#
# 				Search a 2D Matrix
#
#
# 				Python iterative and recursive solutions.
#
# https://discuss.leetcode.com//post/22107
#
# 				Search Insert Position
#
#
# 				Python O(n) and O(lgn) solutions.
#
# https://discuss.leetcode.com//post/79077
#
# 				Search Insert Position
#
#
# 				Python O(n) and O(lgn) solutions.
#
# https://discuss.leetcode.com//post/22094
#
# 				3Sum Closest
#
#
# 				Python solution (two-pointer).
#
# https://discuss.leetcode.com//post/22044
#
# 				Divide Two Integers
#
#
# 				Python solution without using multiplication (bit shift), division and mod operator (only use "+", "-").
#
# https://discuss.leetcode.com//post/78991
#
# 				Divide Two Integers
#
#
# 				Python solution without using multiplication (bit shift), division and mod operator (only use "+", "-").
#
# https://discuss.leetcode.com//post/22011
#
# 				Find Peak Element
#
#
# 				Python iterative and recursive solutions.
#
# https://discuss.leetcode.com//post/22272
#
# 				Binary Search Tree Iterator
#
#
# 				Simple Python solution
#
# https://discuss.leetcode.com//post/79336
#
# 				3Sum
#
#
# 				Python O(n^2) TLE why?
#
# https://discuss.leetcode.com//post/79251
#
# 				Rotate Image
#
#
# 				One line python solution
#
# https://discuss.leetcode.com//post/79241
#
# 				Sort Colors
#
#
# 				Python count sort and one pass sort.
#
# https://discuss.leetcode.com//post/22202
#
# 				Spiral Matrix II
#
#
# 				Python easy to follow solution.
#
# https://discuss.leetcode.com//post/22190
#
# 				Spiral Matrix
#
#
# 				Python easy to understand solution (left, right, top, down).
#
# https://discuss.leetcode.com//post/22179
#
# 				Spiral Matrix
#
#
# 				An iterative Python solution
#
# https://discuss.leetcode.com//post/79195
#
# 				Spiral Matrix
#
#
# 				An iterative Python solution
#
# https://discuss.leetcode.com//post/79193
#
# 				Find Minimum in Rotated Sorted Array
#
#
# 				Simple Python recursion method 40ms
#
# https://discuss.leetcode.com//post/79111
#
# 				Majority Element II
#
#
# 				Boyer-Moore Majority Vote algorithm and my elaboration
#
# https://discuss.leetcode.com//post/79464
#
# 				Majority Element II
#
#
# 				Boyer-Moore Majority Vote algorithm and my elaboration
#
# https://discuss.leetcode.com//post/79453
#
# 				Simplify Path
#
#
# 				Python easy to understand solutions with stack and deque.
#
# https://discuss.leetcode.com//post/22319
#
# 				Multiply Strings
#
#
# 				Python easy to understand solution without overflow (with comments).
#
# https://discuss.leetcode.com//post/22316
#
# 				Longest Consecutive Sequence
#
#
# 				Simple O(n) with Explanation - Just walk each streak
#
# https://discuss.leetcode.com//post/79385
#
# 				Majority Element II
#
#
# 				Boyer-Moore Majority Vote algorithm and my elaboration
#
# https://discuss.leetcode.com//post/79382
#
# 				Trapping Rain Water
#
#
# 				7 lines C / C++
#
# https://discuss.leetcode.com//post/79364
#
# 				Container With Most Water
#
#
# 				Links to O(n) solution explanation, and my elaboration
#
# https://discuss.leetcode.com//post/79361
#
# 				Minimum Size Subarray Sum
#
#
# 				Python easy to understand solution with comments.
#
# https://discuss.leetcode.com//post/22283
#
# 				Search in Rotated Sorted Array II
#
#
# 				Python easy to understand solution (with comments).
#
# https://discuss.leetcode.com//post/22278
#
# 				Minimum Depth of Binary Tree
#
#
# 				Python BFS and DFS solutions.
#
# https://discuss.leetcode.com//post/22830
#
# 				Minimum Size Subarray Sum
#
#
# 				Python easy to understand solution with comments.
#
# https://discuss.leetcode.com//post/79792
#
# 				Longest Palindromic Substring
#
#
# 				Python easy to understand solution with comments (from middle to two ends).
#
# https://discuss.leetcode.com//post/79627
#
# 				Longest Palindromic Substring
#
#
# 				Python easy to understand solution with comments (from middle to two ends).
#
# https://discuss.leetcode.com//post/22529
#
# 				Valid Anagram
#
#
# 				Python solutions (sort and dictionary).
#
# https://discuss.leetcode.com//post/22516
#
# 				Integer to Roman
#
#
# 				Python simple solution.
#
# https://discuss.leetcode.com//post/22506
#
# 				Roman to Integer
#
#
# 				Python solutions by using dictionary and array.
#
# https://discuss.leetcode.com//post/79598
#
# 				Roman to Integer
#
#
# 				Python solutions by using dictionary and array.
#
# https://discuss.leetcode.com//post/22504
#
# 				Reverse Words in a String
#
#
# 				My 44 ms python solution
#
# https://discuss.leetcode.com//post/79529
#
# 				Majority Element II
#
#
# 				Boyer-Moore Majority Vote algorithm and my elaboration
#
# https://discuss.leetcode.com//post/79483
#
# 				Maximum Depth of Binary Tree
#
#
# 				Python solution (BFS + deque/queue)
#
# https://discuss.leetcode.com//post/80205
#
# 				Path Sum
#
#
# 				Python solutions (DFS recursively, DFS+stack, BFS+queue)
#
# https://discuss.leetcode.com//post/80204
#
# 				Same Tree
#
#
# 				Python Recursive solution and DFS Iterative solution with stack and BFS Iterative solution with queue
#
# https://discuss.leetcode.com//post/80203
#
# 				Symmetric Tree
#
#
# 				Python short recursive solution.
#
# https://discuss.leetcode.com//post/22939
#
# 				Longest Substring Without Repeating Characters
#
#
# 				Python solution with comments.
#
# https://discuss.leetcode.com//post/22884
#
# 				Add Two Numbers
#
#
# 				Python concise solution.
#
# https://discuss.leetcode.com//post/22877
#
# 				Two Sum
#
#
# 				Python dictionary and two-pointer solutions.
#
# https://discuss.leetcode.com//post/22875
#
# 				Permutations II
#
#
# 				Python easy to understand backtracking solution.
#
# https://discuss.leetcode.com//post/80103
#
# 				Subsets II
#
#
# 				Simple python solution (DFS).
#
# https://discuss.leetcode.com//post/22837
#
# 				Permutations
#
#
# 				Simple Python solution (DFS).
#
# https://discuss.leetcode.com//post/22836
#
# 				Single Number
#
#
# 				Python different solutions.
#
# https://discuss.leetcode.com//post/80240
#
# 				Merge Two Sorted Lists
#
#
# 				Python solutions (iteratively, recursively, iteratively in-place).
#
# https://discuss.leetcode.com//post/22977
#
# 				Convert Sorted Array to Binary Search Tree
#
#
# 				Python simple recursive solution.
#
# https://discuss.leetcode.com//post/22974
#
# 				Construct Binary Tree from Preorder and Inorder Traversal
#
#
# 				Python short recursive solution.
#
# https://discuss.leetcode.com//post/22972
#
# 				Construct Binary Tree from Inorder and Postorder Traversal
#
#
# 				Python short solution (recursively).
#
# https://discuss.leetcode.com//post/22971
#
# 				Binary Tree Preorder Traversal
#
#
# 				Python solutions (recursively and iteratively).
#
# https://discuss.leetcode.com//post/22966
#
# 				Binary Tree Level Order Traversal II
#
#
# 				Python solutions (dfs recursively, dfs+stack, bfs+queue).
#
# https://discuss.leetcode.com//post/22961
#
# 				Invert Binary Tree
#
#
# 				Python solutions (recursively, dfs, bfs).
#
# https://discuss.leetcode.com//post/22956
#
# 				Lowest Common Ancestor of a Binary Search Tree
#
#
# 				Python recursive solution with comments.
#
# https://discuss.leetcode.com//post/22955
#
# 				Minimum Depth of Binary Tree
#
#
# 				Python BFS and DFS solutions.
#
# https://discuss.leetcode.com//post/80210
#
# 				Binary Search Tree Iterator
#
#
# 				Python concise solution (O(lgn) space and O(1) time).
#
# https://discuss.leetcode.com//post/23039
#
# 				Binary Tree Inorder Traversal
#
#
# 				Python recursive and iterative solutions.
#
# https://discuss.leetcode.com//post/23035
#
# 				Kth Smallest Element in a BST
#
#
# 				Python recursive solution (averaged time: O(lg(n)+k) ).
#
# https://discuss.leetcode.com//post/80314
#
# 				Kth Smallest Element in a BST
#
#
# 				Python recursive solution (averaged time: O(lg(n)+k) ).
#
# https://discuss.leetcode.com//post/23030
#
# 				Kth Smallest Element in a BST
#
#
# 				Python iterative solution based on in order traversal by using stack
#
# https://discuss.leetcode.com//post/80311
#
# 				Flatten Binary Tree to Linked List
#
#
# 				Python recursive solution with comments.
#
# https://discuss.leetcode.com//post/23025
#
# 				Count Complete Tree Nodes
#
#
# 				Python O(lgn)*O(lgn) solution with comments.
#
# https://discuss.leetcode.com//post/23018
#
# 				Intersection of Two Linked Lists
#
#
# 				Python solutions (O(m+n) space and O(1) space).
#
# https://discuss.leetcode.com//post/22984
#
# 				Remove Linked List Elements
#
#
# 				Python solutions (O(n) extra space and in-place).
#
# https://discuss.leetcode.com//post/22981
#
# 				Palindrome Linked List
#
#
# 				Python easy to understand solution with comments (operate nodes directly).
#
# https://discuss.leetcode.com//post/80246
#
# 				Swap Nodes in Pairs
#
#
# 				Python concise iterative and recursive solutions.
#
# https://discuss.leetcode.com//post/80350
#
# 				Sort List
#
#
# 				Python merge-sort with comments.
#
# https://discuss.leetcode.com//post/80349
#
# 				Sort List
#
#
# 				Python merge-sort with comments.
#
# https://discuss.leetcode.com//post/23057
#
# 				Remove Duplicates from Sorted List II
#
#
# 				Python in-place solution with dummy head node.
#
# https://discuss.leetcode.com//post/23054
#
# 				Linked List Cycle II
#
#
# 				Python solution with comments.
#
# https://discuss.leetcode.com//post/80342
#
# 				Binary Tree Postorder Traversal
#
#
# 				Python recursive and iterative solutions.
#
# https://discuss.leetcode.com//post/23049
#
# 				Sum Root to Leaf Numbers
#
#
# 				Python solutions (dfs+stack, bfs+queue, dfs recursively).
#
# https://discuss.leetcode.com//post/23048
#
# 				Validate Binary Search Tree
#
#
# 				Python iterative and recursive solutions with comments.
#
# https://discuss.leetcode.com//post/80334
#
# 				Validate Binary Search Tree
#
#
# 				Python iterative and recursive solutions with comments.
#
# https://discuss.leetcode.com//post/23043
#
# 				Binary Search Tree Iterator
#
#
# 				Any suggestion to improve the run time of my python code below?
#
# https://discuss.leetcode.com//post/80322
#
# 				Binary Tree Upside Down
#
#
# 				Python recursive solution with comments.
#
# https://discuss.leetcode.com//post/80411
#
# 				Binary Tree Upside Down
#
#
# 				Python recursive solution with comments.
#
# https://discuss.leetcode.com//post/23110
#
# 				Insertion Sort List
#
#
# 				Python accepted iterative solution (Another solution is about 330ms).
#
# https://discuss.leetcode.com//post/23104
#
# 				Partition List
#
#
# 				Python concise solution with dummy nodes.
#
# https://discuss.leetcode.com//post/23102
#
# 				Convert Sorted List to Binary Search Tree
#
#
# 				Python recursive solution with detailed comments (operate linked-list directly).
#
# https://discuss.leetcode.com//post/23099
#
# 				Reverse Linked List II
#
#
# 				Python one-pass concise solution with comments.
#
# https://discuss.leetcode.com//post/23097
#
# 				Reverse Nodes in k-Group
#
#
# 				Python recursive and iterative solutions with comments.
#
# https://discuss.leetcode.com//post/23095
#
# 				Rotate List
#
#
# 				Python two-pointer solution.
#
# https://discuss.leetcode.com//post/23065
#
# 				Copy List with Random Pointer
#
#
# 				Python solution without using dictionary.
#
# https://discuss.leetcode.com//post/80352
#
# 				Merge k Sorted Lists
#
#
# 				Python concise divide and conquer solution.
#
# https://discuss.leetcode.com//post/23064
#
# 				Add Digits
#
#
# 				Python different solutions.
#
# https://discuss.leetcode.com//post/23344
#
# 				Add Digits
#
#
# 				C++ O(1) Solution
#
# https://discuss.leetcode.com//post/80642
#
# 				Group Anagrams
#
#
# 				Python easy to understand solution with dictionary.
#
# https://discuss.leetcode.com//post/80599
#
# 				Unique Binary Search Trees II
#
#
# 				What is the complexity of my code?
#
# https://discuss.leetcode.com//post/80540
#
# 				Recover Binary Search Tree
#
#
# 				Python iterative solution (average O(lgn) space, one pass).
#
# https://discuss.leetcode.com//post/23255
#
# 				Binary Tree Paths
#
#
# 				Python solutions (dfs+stack, bfs+queue, dfs recursively).
#
# https://discuss.leetcode.com//post/23244
#
# 				Populating Next Right Pointers in Each Node II
#
#
# 				O(n) complexity, but O(log n) memory space
#
# https://discuss.leetcode.com//post/80513
#
# 				Binary Tree Maximum Path Sum
#
#
# 				Python solution with comments.
#
# https://discuss.leetcode.com//post/23128
#
# 				Count Univalue Subtrees
#
#
# 				Python solution with comments (bottom-up).
#
# https://discuss.leetcode.com//post/23115
#
# 				Count Univalue Subtrees
#
#
# 				191 / 197 test cases passed solution
#
# https://discuss.leetcode.com//post/80416
#
# 				Single Number III
#
#
# 				Accepted C++/Java O(n)-time O(1)-space Easy Solution with Detail Explanations
#
# https://discuss.leetcode.com//post/80660
#
# 				Single Number III
#
#
# 				Accepted C++/Java O(n)-time O(1)-space Easy Solution with Detail Explanations
#
# https://discuss.leetcode.com//post/80659
#
# 				Graph Valid Tree
#
#
# 				Maybe the simplest Python solution.
#
# https://discuss.leetcode.com//post/80657
#
# 				Graph Valid Tree
#
#
# 				Maybe the simplest Python solution.
#
# https://discuss.leetcode.com//post/23367
#
# 				Paint House
#
#
# 				Python solutions with different space usages.
#
# https://discuss.leetcode.com//post/23366
#
# 				Single Number III
#
#
# 				3 line Python Code
#
# https://discuss.leetcode.com//post/80651
#
# 				Single Number III
#
#
# 				Python solution with comments.
#
# https://discuss.leetcode.com//post/23359
#
# 				Single Number III
#
#
# 				Accepted C++/Java O(n)-time O(1)-space Easy Solution with Detail Explanations
#
# https://discuss.leetcode.com//post/80650
#
# 				Single Number III
#
#
# 				Accepted C++/Java O(n)-time O(1)-space Easy Solution with Detail Explanations
#
# https://discuss.leetcode.com//post/80649
#
# 				3Sum Smaller
#
#
# 				Python solution with comments.
#
# https://discuss.leetcode.com//post/23348
#
# 				Strobogrammatic Number
#
#
# 				Python solution with dictionary.
#
# https://discuss.leetcode.com//post/23458
#
# 				Shortest Word Distance II
#
#
# 				Python short solution 92ms using dict
#
# https://discuss.leetcode.com//post/80729
#
# 				Shortest Word Distance II
#
#
# 				Python O(m+n) time solution.
#
# https://discuss.leetcode.com//post/23440
#
# 				Shortest Word Distance
#
#
# 				Java solution using minimum difference between 2 sorted arrays
#
# https://discuss.leetcode.com//post/80727
#
# 				Shortest Word Distance
#
#
# 				Python O(n*n) solution with comments.
#
# https://discuss.leetcode.com//post/80722
#
# 				Shortest Word Distance
#
#
# 				Python O(n*n) solution with comments.
#
# https://discuss.leetcode.com//post/23433
#
# 				Group Shifted Strings
#
#
# 				Python easy to understand solution with comments.
#
# https://discuss.leetcode.com//post/23432
#
# 				Flatten 2D Vector
#
#
# 				Python easy to follow solution with comments.
#
# https://discuss.leetcode.com//post/23426
#
# 				Flatten 2D Vector
#
#
# 				Python easy to follow solution with comments.
#
# https://discuss.leetcode.com//post/23421
#
# 				Convert Sorted List to Binary Search Tree
#
#
# 				Python solutions (convert to array first, top-down approach, bottom-up approach)
#
# https://discuss.leetcode.com//post/80705
#
# 				Find Peak Element
#
#
# 				Python iterative and recursive solutions.
#
# https://discuss.leetcode.com//post/80864
#
# 				Min Stack
#
#
# 				Python easy to understand solution using two stacks.
#
# https://discuss.leetcode.com//post/23559
#
# 				Graph Valid Tree
#
#
# 				Maybe the simplest Python solution.
#
# https://discuss.leetcode.com//post/80841
#
# 				Strobogrammatic Number II
#
#
# 				AC clean Java solution
#
# https://discuss.leetcode.com//post/80820
#
# 				Shortest Word Distance III
#
#
# 				Python solution with comments.
#
# https://discuss.leetcode.com//post/23540
#
# 				Convert Sorted List to Binary Search Tree
#
#
# 				Python recursive solution with detailed comments (operate linked-list directly).
#
# https://discuss.leetcode.com//post/80812
#
# 				Reverse Words in a String II
#
#
# 				Python in-place solution.
#
# https://discuss.leetcode.com//post/23488
#
# 				Two Sum II - Input array is sorted
#
#
# 				Python different solutions (two-pointer, dictionary, binary search).
#
# https://discuss.leetcode.com//post/23485
#
# 				Factor Combinations
#
#
# 				Python backtracking solution.
#
# https://discuss.leetcode.com//post/23481
#
# 				Ugly Number II
#
#
# 				Python solution using dp.
#
# https://discuss.leetcode.com//post/23475
#
# 				Binary Tree Postorder Traversal
#
#
# 				Python recursive and iterative solutions.
#
# https://discuss.leetcode.com//post/81000
#
# 				Basic Calculator
#
#
# 				Python solution with comments.
#
# https://discuss.leetcode.com//post/23672
#
# 				Read N Characters Given Read4
#
#
# 				0ms C++ Solution
#
# https://discuss.leetcode.com//post/80994
#
# 				Read N Characters Given Read4 II - Call multiple times
#
#
# 				My python 40ms solution
#
# https://discuss.leetcode.com//post/80983
#
# 				Read N Characters Given Read4 II - Call multiple times
#
#
# 				[Python] Error on line 79
#
# https://discuss.leetcode.com//post/80981
#
# 				Read N Characters Given Read4
#
#
# 				9-line 61ms AC python solution with comments
#
# https://discuss.leetcode.com//post/80978
#
# 				Read N Characters Given Read4
#
#
# 				0ms C++ Solution
#
# https://discuss.leetcode.com//post/80977
#
# 				Evaluate Reverse Polish Notation
#
#
# 				My python consice solution
#
# https://discuss.leetcode.com//post/80968
#
# 				Evaluate Reverse Polish Notation
#
#
# 				Python solution with comments (don't use eval() function).
#
# https://discuss.leetcode.com//post/23650
#
# 				Graph Valid Tree
#
#
# 				Maybe the simplest Python solution.
#
# https://discuss.leetcode.com//post/80876
#
# 				Gas Station
#
#
# 				Based on the question description, the direction should be clockwise.
#
# https://discuss.leetcode.com//post/23769
#
# 				Two Sum III - Data structure design
#
#
# 				Fast and simple AC Python
#
# https://discuss.leetcode.com//post/81092
#
# 				Two Sum III - Data structure design
#
#
# 				Fast and simple AC Python
#
# https://discuss.leetcode.com//post/81085
#
# 				Palindrome Permutation
#
#
# 				Python easy to follow solution.
#
# https://discuss.leetcode.com//post/23745
#
# 				Read N Characters Given Read4
#
#
# 				0ms C++ Solution
#
# https://discuss.leetcode.com//post/81064
#
# 				Partition List
#
#
# 				Python concise solution with dummy nodes.
#
# https://discuss.leetcode.com//post/81059
#
# 				Read N Characters Given Read4
#
#
# 				0ms C++ Solution
#
# https://discuss.leetcode.com//post/81057
#
# 				Reverse Words in a String II
#
#
# 				Python in-place solution.
#
# https://discuss.leetcode.com//post/81055
#
# 				Two Sum III - Data structure design
#
#
# 				I'm wondering who can write Python code to get rid of TLE?
#
# https://discuss.leetcode.com//post/23675
#
# 				Binary Tree Postorder Traversal
#
#
# 				Share my two Python iterative solutions, post-order and modified preorder then reverse
#
# ...
#
# https://discuss.leetcode.com//post/42213
#
# 				Valid Parentheses
#
#
# 				Java concise stack solution.
#
# https://discuss.leetcode.com//post/42039
#
# 				Majority Element
#
#
# 				Java HashMap, Sorting and Moore's majority vote solutions.
#
# https://discuss.leetcode.com//post/43405
#
# 				Contains Duplicate
#
#
# 				Java HashSet and sorting solutions.
#
# https://discuss.leetcode.com//post/43404
#
# 				Contains Duplicate II
#
#
# 				Java HashMap and HashSet solutions.
#
# https://discuss.leetcode.com//post/43402
#
# 				Contains Duplicate II
#
#
# 				Java 5 lines O(n) solution using HashMap
#
# https://discuss.leetcode.com//post/103208
#
# 				Rotate Array
#
#
# 				Java O(n) in-place solution.
#
# https://discuss.leetcode.com//post/43401
#
# 				Shortest Word Distance
#
#
# 				Java O(n) solution.
#
# https://discuss.leetcode.com//post/43398
#
# 				Two Sum
#
#
# 				Java HashMap solution.
#
# https://discuss.leetcode.com//post/43301
#
# 				One Edit Distance
#
#
# 				Java easy to understand solution.
#
# https://discuss.leetcode.com//post/43296
#
# 				Reverse Words in a String II
#
#
# 				Java concise in-place solution.
#
# https://discuss.leetcode.com//post/43285
#
# 				Reverse Words in a String
#
#
# 				Java solution (no trim(), split() are used).
#
# https://discuss.leetcode.com//post/43283
#
# 				Wiggle Sort
#
#
# 				Java concise in-place solution.
#
# https://discuss.leetcode.com//post/43575
#
# 				Triangle
#
#
# 				Java top-down and bottom-up DP solutions.
#
# https://discuss.leetcode.com//post/43572
#
# 				Two Sum II - Input array is sorted
#
#
# 				Java HashMap and two-pointer solution.
#
# https://discuss.leetcode.com//post/43568
#
# 				Remove Element
#
#
# 				Java concise in-place solution.
#
# https://discuss.leetcode.com//post/43417
#
# 				Remove Duplicates from Sorted Array
#
#
# 				Java in-place one pass solution.
#
# https://discuss.leetcode.com//post/43415
#
# 				Plus One
#
#
# 				Java concise solution with early return.
#
# https://discuss.leetcode.com//post/43413
#
# 				Pascal's Triangle
#
#
# 				Java concise solution with explanation.
#
# https://discuss.leetcode.com//post/43410
#
# 				Pascal's Triangle II
#
#
# 				Java O(k) concise solution.
#
# https://discuss.leetcode.com//post/43409
#
# 				Move Zeroes
#
#
# 				Java concise in-place solution.
#
# https://discuss.leetcode.com//post/43407
#
# 				Merge Sorted Array
#
#
# 				Java easy to understand solution.
#
# https://discuss.leetcode.com//post/43406
#
# 				Validate Binary Search Tree
#
#
# 				Java recursive and iterative solutions.
#
# https://discuss.leetcode.com//post/45255
#
# 				Populating Next Right Pointers in Each Node
#
#
# 				Java recursive and iterative solutions.
#
# https://discuss.leetcode.com//post/45251
#
# 				Number of Islands
#
#
# 				Java concise dfs solution.
#
# https://discuss.leetcode.com//post/45250
#
# 				Binary Tree Paths
#
#
# 				Java recursive and iterative solutions.
#
# https://discuss.leetcode.com//post/45247
#
# 				Minimum Depth of Binary Tree
#
#
# 				Java recursive and iterative solutions.
#
# https://discuss.leetcode.com//post/45245
#
# 				Symmetric Tree
#
#
# 				Java recursive and iterative solutions.
#
# https://discuss.leetcode.com//post/45242
#
# 				Symmetric Tree
#
#
# 				Java recursive and iterative solutions.
#
# https://discuss.leetcode.com//post/45241
#
# 				Reverse String
#
#
# 				[JAVA] Simple and Clean with Explanations [6 Solutions]
#
# https://discuss.leetcode.com//post/104781
#
# 				Rising Temperature
#
#
# 				A solusion with time 1025 ms
#
# https://discuss.leetcode.com//post/104676
#
# 				Longest Substring Without Repeating Characters
#
#
# 				Java concise HashMap solution.
#
# https://discuss.leetcode.com//post/43939
#
# 				Reverse Linked List
#
#
# 				Java iterative and recursive solutions.
#
# https://discuss.leetcode.com//post/45776
#
# 				Binary Tree Right Side View
#
#
# 				Java iterative and recursive solutions.
#
# https://discuss.leetcode.com//post/45448
#
# 				Construct Binary Tree from Inorder and Postorder Traversal
#
#
# 				Java recursive solution.
#
# https://discuss.leetcode.com//post/45444
#
# 				Sum Root to Leaf Numbers
#
#
# 				Java iterative and recursive solutions.
#
# https://discuss.leetcode.com//post/45441
#
# 				Path Sum II
#
#
# 				Java recursive and iterative dfs solutions.
#
# https://discuss.leetcode.com//post/45349
#
# 				Construct Binary Tree from Preorder and Inorder Traversal
#
#
# 				Java recursive solution.
#
# https://discuss.leetcode.com//post/45344
#
# 				Convert Sorted List to Binary Search Tree
#
#
# 				Java fast-slow pointer recursive solution.
#
# https://discuss.leetcode.com//post/45342
#
# 				Flatten Binary Tree to Linked List
#
#
# 				Java concise solution.
#
# https://discuss.leetcode.com//post/45341
#
# 				Flatten Binary Tree to Linked List
#
#
# 				Java concise solution.
#
# https://discuss.leetcode.com//post/45340
#
# 				Convert Sorted Array to Binary Search Tree
#
#
# 				Java dfs solution.
#
# https://discuss.leetcode.com//post/45338
#
# 				Sort List
#
#
# 				Java merge sort solution.
#
# https://discuss.leetcode.com//post/45824
#
# 				Linked List Cycle
#
#
# 				Java fast-slow pointers solution.
#
# https://discuss.leetcode.com//post/45821
#
# 				Add Two Numbers
#
#
# 				Java concise solution.
#
# https://discuss.leetcode.com//post/45818
#
# 				Remove Linked List Elements
#
#
# 				Java iterative and recursive solutions.
#
# https://discuss.leetcode.com//post/45785
#
# 				Swap Nodes in Pairs
#
#
# 				Java recursive and iterative solutions.
#
# https://discuss.leetcode.com//post/45784
#
# 				Remove Duplicates from Sorted List
#
#
# 				Java iterative and recursive solutions.
#
# https://discuss.leetcode.com//post/45783
#
# 				Palindrome Linked List
#
#
# 				Java concise two-pointer solution.
#
# https://discuss.leetcode.com//post/45782
#
# 				Remove Nth Node From End of List
#
#
# 				Java concise two-pointer solution.
#
# https://discuss.leetcode.com//post/45781
#
# 				Intersection of Two Linked Lists
#
#
# 				Java two concise solutions.
#
# https://discuss.leetcode.com//post/45779
#
# 				Merge Two Sorted Lists
#
#
# 				Java concise iterative and recursive solutions.
#
# https://discuss.leetcode.com//post/45778
#
# 				Odd Even Linked List
#
#
# 				Java in-place solution.
#
# https://discuss.leetcode.com//post/45852
#
# 				Rotate List
#
#
# 				Java two-pointer solution.
#
# https://discuss.leetcode.com//post/45851
#
# 				Reverse Linked List II
#
#
# 				Java in-place one-pass solution.
#
# https://discuss.leetcode.com//post/45848
#
# 				Partition List
#
#
# 				Java concise solution.
#
# https://discuss.leetcode.com//post/45845
#
# 				Remove Duplicates from Sorted List II
#
#
# 				Java concise iterative solution.
#
# https://discuss.leetcode.com//post/45843
#
# 				Remove Duplicates from Sorted List II
#
#
# 				Java concise iterative solution.
#
# https://discuss.leetcode.com//post/45842
#
# 				Reorder List
#
#
# 				Java iterative in-place solution.
#
# https://discuss.leetcode.com//post/45835
#
# 				Insertion Sort List
#
#
# 				Java iterative and recursive solutions.
#
# https://discuss.leetcode.com//post/45832
#
# 				Insertion Sort List
#
#
# 				Java iterative and recursive solutions.
#
# https://discuss.leetcode.com//post/45831
#
# 				Linked List Cycle II
#
#
# 				Java two-pointer solution.
#
# https://discuss.leetcode.com//post/45829
#
# 				Binary Tree Level Order Traversal II
#
#
# 				Java bfs and dfs solutions.
#
# https://discuss.leetcode.com//post/46193
#
# 				Moving Average from Data Stream
#
#
# 				Java concise queue solution.
#
# https://discuss.leetcode.com//post/46097
#
# 				Binary Tree Level Order Traversal
#
#
# 				Java concise BFS solution.
#
# https://discuss.leetcode.com//post/45984
#
# 				Lowest Common Ancestor of a Binary Search Tree
#
#
# 				Java recursive solutions.
#
# https://discuss.leetcode.com//post/45983
#
# 				Invert Binary Tree
#
#
# 				Java recursive and iterative solutions.
#
# https://discuss.leetcode.com//post/45981
#
# 				Valid Phone Numbers
#
#
# 				My solution using grep
#
# https://discuss.leetcode.com//post/105593
#
# 				Valid Phone Numbers
#
#
# 				1 Line Solution with Egrep and Regular Expression
#
# https://discuss.leetcode.com//post/105592
#
# 				Reverse Nodes in k-Group
#
#
# 				Java recursive and iterative solutions.
#
# https://discuss.leetcode.com//post/45859
#
# 				Copy List with Random Pointer
#
#
# 				Java two easy to understand solutions.
#
# https://discuss.leetcode.com//post/45857
#
# 				Merge k Sorted Lists
#
#
# 				Java recursive solution.
#
# https://discuss.leetcode.com//post/45855
#
# 				Top K Frequent Elements
#
#
# 				*Java* straightforward O(N + (N-k)lg k) solution
#
# https://discuss.leetcode.com//post/105920
#
# 				Kth Smallest Element in a BST
#
#
# 				Java iterative and recursive solutions.
#
# https://discuss.leetcode.com//post/46289
#
# 				Count Complete Tree Nodes
#
#
# 				Java concise solution.
#
# https://discuss.leetcode.com//post/46288
#
# 				Binary Tree Inorder Traversal
#
#
# 				Java recursive and iterative solutions.
#
# https://discuss.leetcode.com//post/46287
#
# 				Lowest Common Ancestor of a Binary Tree
#
#
# 				Java iterative and recursive solutions.
#
# https://discuss.leetcode.com//post/46286
#
# 				Binary Tree Preorder Traversal
#
#
# 				Java recursive and iterative solutions.
#
# https://discuss.leetcode.com//post/46280
#
# 				Binary Search Tree Iterator
#
#
# 				Java concise solution.
#
# https://discuss.leetcode.com//post/46279
#
# 				Binary Search Tree Iterator
#
#
# 				Java concise solution.
#
# https://discuss.leetcode.com//post/46278
#
# 				Unique Binary Search Trees
#
#
# 				Java dp solution.
#
# https://discuss.leetcode.com//post/46275
#
# 				Closest Binary Search Tree Value
#
#
# 				Java concise recursive solution.
#
# https://discuss.leetcode.com//post/46271
#
# 				Count Univalue Subtrees
#
#
# 				Java O(n*n) and O(n) time complexity solutions.
#
# https://discuss.leetcode.com//post/46461
#
# 				Binary Tree Longest Consecutive Sequence
#
#
# 				Java easy to understand recursive solution.
#
# https://discuss.leetcode.com//post/46446
#
# 				Inorder Successor in BST
#
#
# 				Java iterative and recursive solutions.
#
# https://discuss.leetcode.com//post/46440
#
# 				Inorder Successor in BST
#
#
# 				Java iterative and recursive solutions.
#
# https://discuss.leetcode.com//post/46439
#
# 				House Robber III
#
#
# 				Step by step tackling of the problem
#
# https://discuss.leetcode.com//post/105974
#
# 				Unique Binary Search Trees II
#
#
# 				Java recursive solution.
#
# https://discuss.leetcode.com//post/46431
#
# 				Binary Tree Zigzag Level Order Traversal
#
#
# 				Java iterative and recursive solutions.
#
# https://discuss.leetcode.com//post/46424
#
# 				Reverse Vowels of a String
#
#
# 				Java concise two-pointer solution.
#
# https://discuss.leetcode.com//post/46375
#
# 				Top K Frequent Elements
#
#
# 				Java O(n) Solution - Bucket Sort
#
# https://discuss.leetcode.com//post/105924
#
# 				Top K Frequent Elements
#
#
# 				Java max-heap and min-heap solutions.
#
# https://discuss.leetcode.com//post/46371
#
# 				Combinations
#
#
# 				Java easy to understand recursive solution.
#
# https://discuss.leetcode.com//post/46617
#
# 				Gray Code
#
#
# 				Java concise recursive solution.
#
# https://discuss.leetcode.com//post/46615
#
# 				Combination Sum
#
#
# 				Java easy to understand recursive solution.
#
# https://discuss.leetcode.com//post/46608
#
# 				Letter Combinations of a Phone Number
#
#
# 				Java easy to understand recursive solution.
#
# https://discuss.leetcode.com//post/46542
#
# 				Word Search
#
#
# 				Java recursive solution.
#
# https://discuss.leetcode.com//post/46540
#
# 				Generate Parentheses
#
#
# 				Java easy to understand recursive solution.
#
# https://discuss.leetcode.com//post/46536
#
# 				Subsets
#
#
# 				Java concise recursive solution.
#
# https://discuss.leetcode.com//post/46534
#
# 				Binary Tree Maximum Path Sum
#
#
# 				Java concise recursive solution.
#
# https://discuss.leetcode.com//post/46520
#
# 				Recover Binary Search Tree
#
#
# 				Java easy to understand solution.
#
# https://discuss.leetcode.com//post/46466
#
# 				Binary Tree Postorder Traversal
#
#
# 				Java recursive and iterative solutions.
#
# https://discuss.leetcode.com//post/46462
#
# 				Implement Trie (Prefix Tree)
#
#
# 				Java easy to understand solution.
#
# https://discuss.leetcode.com//post/46857
#
# 				Palindrome Partitioning
#
#
# 				Java easy to understand backtracking solution.
#
# https://discuss.leetcode.com//post/46793
#
# 				Restore IP Addresses
#
#
# 				Java easy to understand recursive solution.
#
# https://discuss.leetcode.com//post/46792
#
# 				Permutation Sequence
#
#
# 				Java iterative solution.
#
# https://discuss.leetcode.com//post/46789
#
# 				Permutations II
#
#
# 				Java concise recursive solution.
#
# https://discuss.leetcode.com//post/46784
#
# 				Subsets II
#
#
# 				Java concise recursive solution.
#
# https://discuss.leetcode.com//post/46778
#
# 				Combination Sum II
#
#
# 				Java easy to understand recursive solution.
#
# https://discuss.leetcode.com//post/46776
#
# 				Factor Combinations
#
#
# 				Java easy to understand recursive solution.
#
# https://discuss.leetcode.com//post/46774
#
# 				Combination Sum III
#
#
# 				Java easy to understand recursive solution.
#
# https://discuss.leetcode.com//post/46683
#
# 				Palindrome Number
#
#
# 				Java easy to understand solution.
#
# https://discuss.leetcode.com//post/46624
#
# 				Sum of Left Leaves
#
#
# 				Java iterative and recursive solutions
#
# https://discuss.leetcode.com//post/167259
#
# 				Strobogrammatic Number
#
#
# 				Java two-pointer solution.
#
# https://discuss.leetcode.com//post/51280
#
# 				Happy Number
#
#
# 				Java HashSet iterative solution.
#
# https://discuss.leetcode.com//post/51273
#
# 				Plus One Linked List
#
#
# 				Java solution (reverse the list).
#
# https://discuss.leetcode.com//post/51268
#
# 				Excel Sheet Column Title
#
#
# 				Java concise solution.
#
# https://discuss.leetcode.com//post/49753
#
# 				Count Numbers with Unique Digits
#
#
# 				Java concise dp solution.
#
# https://discuss.leetcode.com//post/49749
#
# 				N-Queens II
#
#
# 				Java easy to understand backtracking solution.
#
# https://discuss.leetcode.com//post/47067
#
# 				N-Queens
#
#
# 				Java easy to understand recursive solution.
#
# https://discuss.leetcode.com//post/47066
#
# 				Palindrome Permutation II
#
#
# 				Java easy to understand recursive solution.
#
# https://discuss.leetcode.com//post/46998
#
# 				Add and Search Word - Data structure design
#
#
# 				Java easy to understand pdfs solution.
#
# https://discuss.leetcode.com//post/46861
